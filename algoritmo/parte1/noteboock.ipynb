# %%
import numpy as np
from classe_principal.teste_rounds import Teste_rounds as Tr
from classe_principal.plot_function import PlotFunction as Pf
from exercicios import *
import matplotlib.pylab as plt
import pandas as pd

# %%
# Função para calcular a moda usando classes (regra de Sturges)
def get_moda(x_opt: np.ndarray):
    # Calcula o número de classes pela regra de Sturges
    n = int(1 + np.log2(len(x_opt)))
    
    # Calcula o intervalo das classes
    range_class = (max(x_opt) - min(x_opt)) / n
    print(f"Intervalo de classe: {range_class}")
    
    # Inicializando o dicionário de frequências das classes
    dict_hist = {}
    
    # Preenchendo o dicionário com as frequências por classe
    for i in range(n):
        limite_inferior = min(x_opt) + i * range_class
        limite_superior = limite_inferior + range_class
        # Filtra os valores que caem no intervalo da classe atual
        freq = len(x_opt[(x_opt >= limite_inferior) & (x_opt < limite_superior)])
        dict_hist[f"{limite_inferior:.5f}/{limite_superior:.5f}"] = freq
    
    # Determinando a moda (classe com a maior frequência)
    moda = max(dict_hist, key=dict_hist.get)
    
    return dict_hist, moda

# %% [markdown]
# ## Função 1

# %% [markdown]
# <div style="text-align: right">
#
# $$f(x_1, x_2) = x_1^2 + x_2^2$$
#
#
# </div>

# %% [markdown]
# #### Hill Climbing

# %%
obj = ex1(Hill_climb, sigma_desvio = 0.1, x_opt= np.array(
    [-100, -100]
))
tester_ex1_HC = Tr(obj)
tester_ex1_HC.rounds()
lista_coordenadas1 = [(x[0], x[1], z) for x, z in zip(tester_ex1_HC.lista_solucoes, tester_ex1_HC.lista_ress)]
Pf.plot(obj.func, lista_coordenadas1, obj.limite)

# %% [markdown]
# ### Local Random Search

# %%
obj = ex1(LRS, sigma_desvio = 0.1)
tester_ex1_LRS = Tr(obj)
tester_ex1_LRS.rounds()
lista_coordenadas2 = [(x[0], x[1], z) for x, z in zip(tester_ex1_LRS.lista_solucoes, tester_ex1_LRS.lista_ress)]
Pf.plot(obj.func, lista_coordenadas2, obj.limite)

# %% [markdown]
# ### Global Random Search

# %%
obj = ex1(GRS)
tester_ex1_GRS = Tr(obj)
tester_ex1_GRS.rounds()
lista_coordenadas3 = [(x[0], x[1], z) for x, z in zip(tester_ex1_GRS.lista_solucoes, tester_ex1_GRS.lista_ress)]
Pf.plot(obj.func, lista_coordenadas3, obj.limite)

# %%
Pf.plot_full(obj.func, lista_coordenadas1, lista_coordenadas2, lista_coordenadas3, obj.limite)

# %% [markdown]
# ## Função 2

# %% [markdown]
# <p style="text-align: right;">
#
# $$
# f(x_1, x_2) = e^{-((x_1^2 + x_2^2))} + 2 \cdot e^{-(x_1 - 1.7)^2 + (x_2 - 1.7)^2}
# $$
# </p>

# %% [markdown]
# ### Hill Climbing

# %%
obj = ex2(Hill_climb, sigma_desvio = 0.1, x_opt = np.array(
    [-2, -2]
))
tester_ex2_HC = Tr(obj)
tester_ex2_HC.rounds()
lista_coordenadas1 = [(x[0], x[1], z) for x, z in zip(tester_ex2_HC.lista_solucoes, tester_ex2_HC.lista_ress)]
Pf.plot(obj.func, lista_coordenadas1, obj.limite)

# %% [markdown]
# ### Local Random Search

# %%
obj = ex2(LRS, sigma_desvio = 0.1)
tester_ex2_LRS = Tr(obj)
tester_ex2_LRS.rounds()
lista_coordenadas2 = [(x[0], x[1], z) for x, z in zip(tester_ex2_LRS.lista_solucoes, tester_ex2_LRS.lista_ress)]
Pf.plot(obj.func, lista_coordenadas2, obj.limite)

# %% [markdown]
# ### Global Randon Search

# %%
obj = ex2(GRS)
tester_ex2_GRS = Tr(obj)
tester_ex2_GRS.rounds()
lista_coordenadas3 = [(x[0], x[1], z) for x, z in zip(tester_ex2_GRS.lista_solucoes, tester_ex2_GRS.lista_ress)]
Pf.plot(obj.func, lista_coordenadas3, obj.limite)

# %%
Pf.plot_full(obj.func, lista_coordenadas1, lista_coordenadas2, lista_coordenadas3, obj.limite)

# %% [markdown]
# ## Função 3

# %% [markdown]
# $$
# f(x_1, x_2) = -20 \cdot e^{-0.2 \cdot \sqrt{0.5 \cdot (x_1^2 + x_2^2)}} - e^{0.5 \cdot (\cos(2 \pi x_1) + \cos(2 \pi x_2))} + 20 + e^1
# $$

# %% [markdown]
# ### Hill Climbing

# %%
obj = ex3(Hill_climb, sigma_desvio=.874, x_opt=np.array(
    [-8, -8]
))
tester_ex3_HC = Tr(obj)
tester_ex3_HC.rounds()
lista_coordenadas = [(x[0], x[1], z) for x, z in zip(tester_ex3_HC.lista_solucoes, tester_ex3_HC.lista_ress)]
Pf.plot(obj.func, lista_coordenadas, obj.limite)

# %% [markdown]
# ### Local Random Search

# %%
obj = ex3(LRS, sigma_desvio = .4)
tester_ex3_LRS = Tr(obj)
tester_ex3_LRS.rounds()
lista_coordenadas = [(x[0], x[1], z) for x, z in zip(tester_ex3_LRS.lista_solucoes, tester_ex3_LRS.lista_ress)]
Pf.plot(obj.func, lista_coordenadas, obj.limite)

# %% [markdown]
# ### Global Random Search

# %%
obj = ex3(GRS)
tester_ex3_GRS = Tr(obj)
tester_ex3_GRS.rounds()
lista_coordenadas = [(x[0], x[1], z) for x, z in zip(tester_ex3_GRS.lista_solucoes, tester_ex3_GRS.lista_ress)]
Pf.plot(obj.func, lista_coordenadas, obj.limite)

# %% [markdown]
# ## Função 4

# %% [markdown]
# $$
# f(x_1, x_2) = (x_1^2 - 10 \cdot \cos(2\pi x_1) + 10) + (x_2^2 - 10 \cdot \cos(2\pi x_2) + 10)
# $$

# %% [markdown]
# ### Hill Climbing

# %%
obj = ex4(Hill_climb, sigma_desvio = .9, x_opt=np.array(
    [-5.12, -5.12]
))
tester_ex4_HC = Tr(obj)
tester_ex4_HC.rounds()
lista_coordenadas = [(x[0], x[1], z) for x, z in zip(tester_ex4_HC.lista_solucoes, tester_ex4_HC.lista_ress)]
Pf.plot(obj.func, lista_coordenadas, obj.limite)

# %% [markdown]
# ### Local Random Search

# %%
obj = ex4(LRS, sigma_desvio = 0.9)
tester_ex4_LRS = Tr(obj)
tester_ex4_LRS.rounds()
lista_coordenadas = [(x[0], x[1], z) for x, z in zip(tester_ex4_LRS.lista_solucoes, tester_ex4_LRS.lista_ress)]
Pf.plot(obj.func, lista_coordenadas, obj.limite)

# %% [markdown]
# ### Global Random Search

# %%
obj = ex4(GRS)
tester_ex4_GRS = Tr(obj)
tester_ex4_GRS.rounds()
lista_coordenadas = [(x[0], x[1], z) for x, z in zip(tester_ex4_GRS.lista_solucoes, tester_ex4_GRS.lista_ress)]
Pf.plot(obj.func, lista_coordenadas, obj.limite)

# %% [markdown]
# ## Função 5

# %% [markdown]
# $$
# f(x_1, x_2) = \frac{x_1 \cdot \cos(x_1)}{20} + 2 \cdot e^{-(x_1)^{2} - (x_2-1)^{2}} + 0.01 \cdot x_1 \cdot x_2
# $$

# %% [markdown]
# ### Hill Climbing

# %%
obj = ex5(Hill_climb, sigma_desvio = 0.1, x_opt = np.array(
    [-10, -10]
))
tester_ex5_HC = Tr(obj)
tester_ex5_HC.rounds()
lista_coordenadas = [(x[0], x[1], z) for x, z in zip(tester_ex5_HC.lista_solucoes, tester_ex5_HC.lista_ress)]
Pf.plot(obj.func, lista_coordenadas, obj.limite)

# %% [markdown]
# ### Local Random Serach

# %%
obj = ex5(LRS, sigma_desvio = 0.9)
tester_ex5_LRS = Tr(obj)
tester_ex5_LRS.rounds()
lista_coordenadas = [(x[0], x[1], z) for x, z in zip(tester_ex5_LRS.lista_solucoes, tester_ex5_LRS.lista_ress)]
Pf.plot(obj.func, lista_coordenadas, obj.limite)

# %% [markdown]
# ### Global Random Search

# %%
obj = ex5(GRS)
tester_ex5_GRS = Tr(obj)
tester_ex5_GRS.rounds()
lista_coordenadas = [(x[0], x[1], z) for x, z in zip(tester_ex5_GRS.lista_solucoes, tester_ex5_GRS.lista_ress)]
Pf.plot(obj.func, lista_coordenadas, obj.limite)

# %% [markdown]
# ## Função 6

# %% [markdown]
# $$
# f(x_1, x_2) = x_1 \cdot \sin(4\pi x_1) - x_2 \cdot \sin(4\pi x_2 + \pi) + 1
# $$

# %% [markdown]
# ### Hill Climbing

# %%
obj = ex6(Hill_climb, sigma_desvio = 0.5, x_opt=np.array(
    [-1, -1]
))
tester_ex6_HC = Tr(obj)
tester_ex6_HC.rounds()
lista_coordenadas = [(x[0], x[1], z) for x, z in zip(tester_ex6_HC.lista_solucoes, tester_ex6_HC.lista_ress)]
Pf.plot(obj.func, lista_coordenadas, obj.limite)

# %% [markdown]
# ### Local Random Search

# %%
obj = ex6(LRS, sigma_desvio = 0.3)
tester_ex6_LRS = Tr(obj)
tester_ex6_LRS.rounds()
lista_coordenadas = [(x[0], x[1], z) for x, z in zip(tester_ex6_LRS.lista_solucoes, tester_ex6_LRS.lista_ress)]
Pf.plot(obj.func, lista_coordenadas, obj.limite)

# %% [markdown]
# ### Global Random Search

# %%
obj = ex6(GRS)
tester_ex6_GRS = Tr(obj)
tester_ex6_GRS.rounds()
lista_coordenadas = [(x[0], x[1], z) for x, z in zip(tester_ex6_GRS.lista_solucoes, tester_ex6_GRS.lista_ress)]
Pf.plot(obj.func, lista_coordenadas, obj.limite)

# %% [markdown]
# ## Função 7

# %% [markdown]
# $$
# f(x_1, x_2) = - \sin(x_1) \cdot \sin(x_1^{2}/\pi)^{2 \cdot 10} - \sin(x_2) \sin(2 x_2^{2}/\pi)^{2 \cdot 10}
# $$

# %% [markdown]
# ### Hill Climbing

# %%
obj = ex7(Hill_climb, sigma_desvio = 0.1,x_opt= np.array(
    [0, 0]
))
tester_ex7_HC = Tr(obj)
tester_ex7_HC.rounds()
lista_coordenadas = [(x[0], x[1], z) for x, z in zip(tester_ex7_HC.lista_solucoes, tester_ex7_HC.lista_ress)]
Pf.plot(obj.func, lista_coordenadas, obj.limite)

# %% [markdown]
# ### Local Random Search

# %%
obj = ex7(LRS, sigma_desvio = 0.1)
tester_ex7_LRS = Tr(obj)
tester_ex7_LRS.rounds()
lista_coordenadas = [(x[0], x[1], z) for x, z in zip(tester_ex7_LRS.lista_solucoes, tester_ex7_LRS.lista_ress)]
Pf.plot(obj.func, lista_coordenadas, obj.limite)

# %% [markdown]
# ### Global Random Search

# %%
obj = ex7(GRS)
tester_ex7_GRS = Tr(obj)
tester_ex7_GRS.rounds()
lista_coordenadas = [(x[0], x[1], z) for x, z in zip(tester_ex7_GRS.lista_solucoes, tester_ex7_GRS.lista_ress)]
Pf.plot(obj.func, lista_coordenadas, obj.limite)

# %% [markdown]
# ## Função 8

# %% [markdown]
# $$
# f(x_1, x_2) = -(x_2 + 47) \cdot \sin(\sqrt{|x_1/2 + (x_2 + 47)|}) - x_1 \cdot \sin(\sqrt{|x_1 - (x_2 + 47)|})
# $$

# %% [markdown]
# ### Hill Climbing

# %%
obj = ex8(Hill_climb, sigma_desvio = 0.1, x_opt=np.array(
    [-200, -200]
))
tester_ex8_HC = Tr(obj)
tester_ex8_HC.rounds()
lista_coordenadas = [(x[0], x[1], z) for x, z in zip(tester_ex8_HC.lista_solucoes, tester_ex8_HC.lista_ress)]
Pf.plot(obj.func, lista_coordenadas, obj.limite)

# %% [markdown]
# ### Local Random Search

# %%
obj = ex8(LRS, sigma_desvio = 0.9)
tester_ex8_LRS = Tr(obj)
tester_ex8_LRS.rounds()
lista_coordenadas = [(x[0], x[1], z) for x, z in zip(tester_ex8_LRS.lista_solucoes, tester_ex8_LRS.lista_ress)]
Pf.plot(obj.func, lista_coordenadas, obj.limite)

# %% [markdown]
# ### Global Random Search

# %%
obj = ex8(GRS)
tester_ex8_GRS = Tr(obj)
tester_ex8_GRS.rounds()
lista_coordenadas = [(x[0], x[1], z) for x, z in zip(tester_ex8_GRS.lista_solucoes, tester_ex8_GRS.lista_ress)]
Pf.plot(obj.func, lista_coordenadas, obj.limite)

# %% [markdown]
# ## Tabela

# %%
# função para achar classe de maior freqência
def get_moda(array):
    count, bins = np.histogram(array, bins = "sturges")
    max_freq_index = np.argmax(count)
    bin_start = bins[max_freq_index]
    bin_end = bins[max_freq_index+1]
    return "{:.3f}/{:.3f}".format(bin_start, bin_end)

# %%
# Função 1
# respectivamente HC, LRS, GRS
ex1_list_moda = list()
ex1_list_moda.append(get_moda(tester_ex1_HC.lista_ress))
ex1_list_moda.append(get_moda(tester_ex1_LRS.lista_ress))
ex1_list_moda.append(get_moda(tester_ex1_GRS.lista_ress))
print(ex1_list_moda)
# Out:
# ['0.000/0.000', '0.000/0.000', '1.054/95.824']

# %%
import matplotlib.pyplot as plt


dados_HC = tester_ex1_HC.lista_ress
dados_LRS = tester_ex1_LRS.lista_ress
dados_GRS = tester_ex1_GRS.lista_ress

# Criar a figura e os subplots (1 linha e 3 colunas)
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

# Plotar os histogramas em cada subplot
axes[0].hist(dados_HC, bins='sturges', color='blue', alpha=0.7)
axes[0].set_title('Hill Climbing')
axes[0].set_xlabel('Valores')
axes[0].set_ylabel('Frequência')

axes[1].hist(dados_LRS, bins='sturges', color='green', alpha=0.7)
axes[1].set_title('Local Random Search')
axes[1].set_xlabel('Valores')

axes[2].hist(dados_GRS, bins='sturges', color='red', alpha=0.7)
axes[2].set_title('Global Random Search')
axes[2].set_xlabel('Valores')

plt.tight_layout()

# Exibir o gráfico
plt.show()

# %%
# Fução 2
# respectivamente HC, LRS, GRS
ex2_list_moda = list()
ex2_list_moda.append(get_moda(tester_ex2_HC.lista_ress))
ex2_list_moda.append(get_moda(tester_ex2_LRS.lista_ress))
ex2_list_moda.append(get_moda(tester_ex2_GRS.lista_ress))
print(ex2_list_moda)
# Out:
# ['1.006/1.006', '1.878/2.003', '1.932/2.001']

# %%
import matplotlib.pyplot as plt

dados_HC = tester_ex2_HC.lista_ress
dados_LRS = tester_ex2_LRS.lista_ress
dados_GRS = tester_ex2_GRS.lista_ress

# Criar a figura e os subplots (1 linha e 3 colunas)
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

# Plotar os histogramas em cada subplot
axes[0].hist(dados_HC, bins='sturges', color='blue', alpha=0.7)
axes[0].set_title('Hill Climbing')
axes[0].set_xlabel('Valores')
axes[0].set_ylabel('Frequência')

axes[1].hist(dados_LRS, bins='sturges', color='green', alpha=0.7)
axes[1].set_title('Local Random Search')
axes[1].set_xlabel('Valores')

axes[2].hist(dados_GRS, bins='sturges', color='red', alpha=0.7)
axes[2].set_title('Global Random Search')
axes[2].set_xlabel('Valores')

plt.tight_layout()

# Exibir o gráfico
plt.show()

# %%
# Fução 3
# respectivamente HC, LRS, GRS
ex3_list_moda = list()
ex3_list_moda.append(get_moda(tester_ex3_HC.lista_ress))
ex3_list_moda.append(get_moda(tester_ex3_LRS.lista_ress))
ex3_list_moda.append(get_moda(tester_ex3_GRS.lista_ress))
print(ex3_list_moda)
# Out:
# ['13.996/15.962', '0.018/1.960', '2.697/3.419']

# %%
import matplotlib.pyplot as plt


dados_HC = tester_ex3_HC.lista_ress
dados_LRS = tester_ex3_LRS.lista_ress
dados_GRS = tester_ex3_GRS.lista_ress

# Criar a figura e os subplots (1 linha e 3 colunas)
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

# Plotar os histogramas em cada subplot
axes[0].hist(dados_HC, bins='sturges', color='blue', alpha=0.7)
axes[0].set_title('Hill Climbing')
axes[0].set_xlabel('Valores')
axes[0].set_ylabel('Frequência')

axes[1].hist(dados_LRS, bins='sturges', color='green', alpha=0.7)
axes[1].set_title('Local Random Search')
axes[1].set_xlabel('Valores')

axes[2].hist(dados_GRS, bins='sturges', color='red', alpha=0.7)
axes[2].set_title('Global Random Search')
axes[2].set_xlabel('Valores')

plt.tight_layout()

# Exibir o gráfico
plt.show()

# %%
# Fução 4
# respectivamente HC, LRS, GRS
ex4_list_moda = list()
ex4_list_moda.append(get_moda(tester_ex4_HC.lista_ress))
ex4_list_moda.append(get_moda(tester_ex4_LRS.lista_ress))
ex4_list_moda.append(get_moda(tester_ex4_GRS.lista_ress))
print(ex4_list_moda)
# Out:
# ['1.037/7.217', '0.005/1.380', '3.255/4.780']

# %%
import matplotlib.pyplot as plt

dados_HC = tester_ex4_HC.lista_ress
dados_LRS = tester_ex4_LRS.lista_ress
dados_GRS = tester_ex4_GRS.lista_ress

# Criar a figura e os subplots (1 linha e 3 colunas)
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

# Plotar os histogramas em cada subplot
axes[0].hist(dados_HC, bins='sturges', color='blue', alpha=0.7)
axes[0].set_title('Hill Climbing')
axes[0].set_xlabel('Valores')
axes[0].set_ylabel('Frequência')

axes[1].hist(dados_LRS, bins='sturges', color='green', alpha=0.7)
axes[1].set_title('Local Random Search')
axes[1].set_xlabel('Valores')

axes[2].hist(dados_GRS, bins='sturges', color='red', alpha=0.7)
axes[2].set_title('Global Random Search')
axes[2].set_xlabel('Valores')

plt.tight_layout()

# Exibir o gráfico
plt.show()

# %%
# Fução 5
# respectivamente HC, LRS, GRS
ex5_list_moda = list()
ex5_list_moda.append(get_moda(tester_ex5_HC.lista_ress))
ex5_list_moda.append(get_moda(tester_ex5_LRS.lista_ress))
ex5_list_moda.append(get_moda(tester_ex5_GRS.lista_ress))
print(ex5_list_moda)
# Out:
# ['1.437/1.437', '0.849/1.079', '1.291/1.428']

# %%
import matplotlib.pyplot as plt

# Supondo que você tenha três listas de dados
dados_HC = tester_ex5_HC.lista_ress
dados_LRS = tester_ex5_LRS.lista_ress
dados_GRS = tester_ex5_GRS.lista_ress

# Criar a figura e os subplots (1 linha e 3 colunas)
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

# Plotar os histogramas em cada subplot
axes[0].hist(dados_HC, bins='sturges', color='blue', alpha=0.7)
axes[0].set_title('Hill Climbing')
axes[0].set_xlabel('Valores')
axes[0].set_ylabel('Frequência')

axes[1].hist(dados_LRS, bins='sturges', color='green', alpha=0.7)
axes[1].set_title('Local Random Search')
axes[1].set_xlabel('Valores')

axes[2].hist(dados_GRS, bins='sturges', color='red', alpha=0.7)
axes[2].set_title('Global Random Search')
axes[2].set_xlabel('Valores')

plt.tight_layout()

# Exibir o gráfico
plt.show()

# %%
# Fução 6
# respectivamente HC, LRS, GRS
ex6_list_moda = list()
ex6_list_moda.append(get_moda(tester_ex6_HC.lista_ress))
ex6_list_moda.append(get_moda(tester_ex6_LRS.lista_ress))
ex6_list_moda.append(get_moda(tester_ex6_GRS.lista_ress))
print(ex6_list_moda)
# Out:
# ['1.986/2.237', '4.184/4.700', '4.918/5.248']

# %%
import matplotlib.pyplot as plt


dados_HC = tester_ex6_HC.lista_ress
dados_LRS = tester_ex6_LRS.lista_ress
dados_GRS = tester_ex6_GRS.lista_ress

# Criar a figura e os subplots (1 linha e 3 colunas)
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

# Plotar os histogramas em cada subplot
axes[0].hist(dados_HC, bins='sturges', color='blue', alpha=0.7)
axes[0].set_title('Hill Climbing')
axes[0].set_xlabel('Valores')
axes[0].set_ylabel('Frequência')

axes[1].hist(dados_LRS, bins='sturges', color='green', alpha=0.7)
axes[1].set_title('Local Random Search')
axes[1].set_xlabel('Valores')

axes[2].hist(dados_GRS, bins='sturges', color='red', alpha=0.7)
axes[2].set_title('Global Random Search')
axes[2].set_xlabel('Valores')

plt.tight_layout()

# Exibir o gráfico
plt.show()

# %%
# Fução 7
# respectivamente HC, LRS, GRS
ex7_list_moda = list()
ex7_list_moda.append(get_moda(tester_ex7_HC.lista_ress))
ex7_list_moda.append(get_moda(tester_ex7_LRS.lista_ress))
ex7_list_moda.append(get_moda(tester_ex7_GRS.lista_ress))
print(ex7_list_moda)
# Out:
# ['-1.051/-0.926', '-1.107/-0.933', '-1.582/-1.477']

# %%
import matplotlib.pyplot as plt


dados_HC = tester_ex7_HC.lista_ress
dados_LRS = tester_ex7_LRS.lista_ress
dados_GRS = tester_ex7_GRS.lista_ress

# Criar a figura e os subplots (1 linha e 3 colunas)
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

# Plotar os histogramas em cada subplot
axes[0].hist(dados_HC, bins='sturges', color='blue', alpha=0.7)
axes[0].set_title('Hill Climbing')
axes[0].set_xlabel('Valores')
axes[0].set_ylabel('Frequência')

axes[1].hist(dados_LRS, bins='sturges', color='green', alpha=0.7)
axes[1].set_title('Local Random Search')
axes[1].set_xlabel('Valores')

axes[2].hist(dados_GRS, bins='sturges', color='red', alpha=0.7)
axes[2].set_title('Global Random Search')
axes[2].set_xlabel('Valores')

plt.tight_layout()

# Exibir o gráfico
plt.show()

# %%
# Fução 8
# respectivamente HC, LRS, GRS
ex8_list_moda = list()
ex8_list_moda.append(get_moda(tester_ex8_HC.lista_ress))
ex8_list_moda.append(get_moda(tester_ex8_LRS.lista_ress))
ex8_list_moda.append(get_moda(tester_ex8_GRS.lista_ress))
print(ex8_list_moda)
# Out:
# ['-148.392/-148.392', '-211.180/-169.713', '-210.942/-203.808']

# %%
import matplotlib.pyplot as plt


dados_HC = tester_ex8_HC.lista_ress
dados_LRS = tester_ex8_LRS.lista_ress
dados_GRS = tester_ex8_GRS.lista_ress

# Criar a figura e os subplots (1 linha e 3 colunas)
fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)

# Plotar os histogramas em cada subplot
axes[0].hist(dados_HC, bins='sturges', color='blue', alpha=0.7)
axes[0].set_title('Hill Climbing')
axes[0].set_xlabel('Valores')
axes[0].set_ylabel('Frequência')

axes[1].hist(dados_LRS, bins='sturges', color='green', alpha=0.7)
axes[1].set_title('Local Random Search')
axes[1].set_xlabel('Valores')

axes[2].hist(dados_GRS, bins='sturges', color='red', alpha=0.7)
axes[2].set_title('Global Random Search')
axes[2].set_xlabel('Valores')

plt.tight_layout()

# Exibir o gráfico
plt.show()

# %%
df = pd.DataFrame({
    'Função': ['Ex1', 'Ex2', 'Ex3', 'Ex4', 'Ex5', 'Ex6', 'Ex7', 'Ex8'],
    'HC': [ex1_list_moda[0], ex2_list_moda[0], ex3_list_moda[0], ex4_list_moda[0],
           ex5_list_moda[0], ex6_list_moda[0], ex7_list_moda[0], ex8_list_moda[0]],
    'LRS': [ex1_list_moda[1], ex2_list_moda[1], ex3_list_moda[1], ex4_list_moda[1],
            ex5_list_moda[1], ex6_list_moda[1], ex7_list_moda[1], ex8_list_moda[1]],
    'GRS': [ex1_list_moda[2], ex2_list_moda[2], ex3_list_moda[2], ex4_list_moda[2],
            ex5_list_moda[2], ex6_list_moda[2], ex7_list_moda[2], ex8_list_moda[2]],
    'Mim/Max':["Min", "Max", "Min", "Min", "Max",
               "Max", "Min", "Min" ]
})

# Exibir a tabela
print(df)

# Salvar como CSV (se necessário)
df.to_csv('resultados_exercicios.csv', index=False)
# Out:
#   Função                 HC                LRS                GRS Mim/Max
# 0    Ex1        0.000/0.000        0.000/0.000       1.054/95.824     Min
# 1    Ex2        1.006/1.006        1.878/2.003        1.932/2.001     Max
# 2    Ex3      13.996/15.962        0.018/1.960        2.697/3.419     Min
# 3    Ex4        1.037/7.217        0.005/1.380        3.255/4.780     Min
# 4    Ex5        1.437/1.437        0.849/1.079        1.291/1.428     Max
# 5    Ex6        1.986/2.237        4.184/4.700        4.918/5.248     Max
# 6    Ex7      -1.051/-0.926      -1.107/-0.933      -1.582/-1.477     Min
# 7    Ex8  -148.392/-148.392  -211.180/-169.713  -210.942/-203.808     Min
